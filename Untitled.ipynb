# %%
import pandas as pd

# %%
data = pd.read_csv("E:\VISUALISASI\DATABASE\CSV\MPNSPM.csv", sep = ";", low_memory =False)
df_ektrak =data[['MPN_NPWP','MPN_NAMA WP','AR','SEKSI','KLU','Kategori','klu_nama'
                   ]]
df_ektrak.dtypes
df_ektrak
# Out:
#               MPN_NPWP             MPN_NAMA WP                AR     SEKSI  \
# 0       13007026007000  GOBEL DHARMA NUSANTARA  DJAINI KURNIAWAN  Waskon 3
# 1       13007026007000  GOBEL DHARMA NUSANTARA  DJAINI KURNIAWAN  Waskon 3
# 2       13007026007000  GOBEL DHARMA NUSANTARA  DJAINI KURNIAWAN  Waskon 3
# 3       13007026007000  GOBEL DHARMA NUSANTARA  DJAINI KURNIAWAN  Waskon 3
# 4       13007026007000  GOBEL DHARMA NUSANTARA  DJAINI KURNIAWAN  Waskon 3
# ...                ...                     ...               ...       ...
# 552690  24483059009000         BINTANG SHAFWAN      WILLI SUJITA  Waskon 2
# 552691  24483059009000         BINTANG SHAFWAN      WILLI SUJITA  Waskon 2
# 552692  10017044059000      KADI INTERNATIONAL     WIDI SUBIYONO  Waskon 2
# 552693  10017044059000      KADI INTERNATIONAL     WIDI SUBIYONO  Waskon 2
# 552694  13859343423000     ITAMA RANORAYA TBK.               NaN       NaN
#
# ...

# %%
df_ektrak.KLU = df_ektrak.KLU.astype(int) 
df_ektrak.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5c88d00f2723> in <module>
# ----> 1 df_ektrak.KLU = df_ektrak.KLU.astype(int)
#       2 df_ektrak.dtypes
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
# ...
